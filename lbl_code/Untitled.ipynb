# %%
import numpy as np
import pandas as pd
import os
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from multiprocessing import Pool as ThreadPool
from datetime import datetime
import time
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_selection import chi2,SelectKBest
from sklearn.utils import shuffle
from tqdm import tqdm

# %%
data_dir='/home/uniml/work/hw/dataset/'
temp_save_dir='./temp_data/'
age_train_file_path=data_dir+'age_train.csv'
age_test_file_path=data_dir+'age_test.csv'
app_info_file_path=data_dir+'app_info.csv'
user_app_actived_file_path=data_dir+'user_app_actived.csv'
user_basic_info_file_path=data_dir+'user_basic_info.csv'
user_behavior_info_file_path=data_dir+'user_behavior_info.csv'
user_app_usage_file_path=data_dir+'user_app_usage.csv'

# %%
#用户label数据
#在此将对应的label减去1以方便模型操作,后面预测的时候会加回来
age_train=pd.read_csv(age_train_file_path,header=None,names=['uId','age_group'])
age_train.age_group=age_train.age_group.apply(lambda x:x-1)
age_train.age_group=age_train.age_group.astype('category')
age_test=pd.read_csv(age_test_file_path,header=None,names=['id'])

# %%
age_train['age_group'].value_counts()/len(age_train)
# Out:
# 3    0.200
# 2    0.200
# 4    0.175
# 1    0.175
# 5    0.125
# 0    0.125
# Name: age_group, dtype: float64

# %%
age_test['label']=3

# %%
age_test.to_csv('submission.csv',index=False)

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0824 07:24:22.777909 140606629578560 deprecation_wrapper.py:119] From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0824 07:24:22.778816 140606629578560 deprecation_wrapper.py:119] From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0824 07:24:22.779249 140606629578560 deprecation_wrapper.py:119] From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0824 07:24:27.280978 140606629578560 deprecation_wrapper.py:119] From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# ['/job:localhost/replica:0/task:0/device:GPU:0',
#  '/job:localhost/replica:0/task:0/device:GPU:1',
#  '/job:localhost/replica:0/task:0/device:GPU:2',
#  '/job:localhost/replica:0/task:0/device:GPU:3',
#  '/job:localhost/replica:0/task:0/device:GPU:4',
#  '/job:localhost/replica:0/task:0/device:GPU:5',
#  '/job:localhost/replica:0/task:0/device:GPU:6',
#  '/job:localhost/replica:0/task:0/device:GPU:7']

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17297443503901884829, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 10818167890290390782
#  physical_device_desc: "device: XLA_CPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 1
#    links {
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 7211610578764766988
#  physical_device_desc: "device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:2d:00.0, compute capability: 7.0", name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 10030408539594501251
#  physical_device_desc: "device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0000:32:00.0, compute capability: 7.0", name: "/device:GPU:2"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 12654068014023913466
#  physical_device_desc: "device: 2, name: Tesla V100-SXM2-32GB, pci bus id: 0000:5b:00.0, compute capability: 7.0", name: "/device:GPU:3"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 13163477812745248090
#  physical_device_desc: "device: 3, name: Tesla V100-SXM2-32GB, pci bus id: 0000:5f:00.0, compute capability: 7.0", name: "/device:GPU:4"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 17493402715135256538
#  physical_device_desc: "device: 4, name: Tesla V100-SXM2-32GB, pci bus id: 0000:b5:00.0, compute capability: 7.0", name: "/device:GPU:5"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 2914551881451136117
#  physical_device_desc: "device: 5, name: Tesla V100-SXM2-32GB, pci bus id: 0000:be:00.0, compute capability: 7.0", name: "/device:GPU:6"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 16947005807677701012
#  physical_device_desc: "device: 6, name: Tesla V100-SXM2-32GB, pci bus id: 0000:e1:00.0, compute capability: 7.0", name: "/device:GPU:7"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 6665586022550041693
#  physical_device_desc: "device: 7, name: Tesla V100-SXM2-32GB, pci bus id: 0000:e9:00.0, compute capability: 7.0", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 7514499989391768572
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:1"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 5294805770515361662
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:2"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6114708282373380646
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:3"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1768537789084294185
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:4"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 13430065370807135077
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:5"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1052152016729659991
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:6"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 8418722741641046592
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:7"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6939589720955380650
#  physical_device_desc: "device: XLA_GPU device"]

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 12006150996960608790, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3063380831198680293
#  physical_device_desc: "device: XLA_CPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 1
#    links {
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 15588897657807698061
#  physical_device_desc: "device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:2d:00.0, compute capability: 7.0", name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 1677033382156657115
#  physical_device_desc: "device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0000:32:00.0, compute capability: 7.0", name: "/device:GPU:2"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 11940318155664585007
#  physical_device_desc: "device: 2, name: Tesla V100-SXM2-32GB, pci bus id: 0000:5b:00.0, compute capability: 7.0", name: "/device:GPU:3"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 7097757587283126572
#  physical_device_desc: "device: 3, name: Tesla V100-SXM2-32GB, pci bus id: 0000:5f:00.0, compute capability: 7.0", name: "/device:GPU:4"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 14474868323744233439
#  physical_device_desc: "device: 4, name: Tesla V100-SXM2-32GB, pci bus id: 0000:b5:00.0, compute capability: 7.0", name: "/device:GPU:5"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 15013179972481474627
#  physical_device_desc: "device: 5, name: Tesla V100-SXM2-32GB, pci bus id: 0000:be:00.0, compute capability: 7.0", name: "/device:GPU:6"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 718935409751249157
#  physical_device_desc: "device: 6, name: Tesla V100-SXM2-32GB, pci bus id: 0000:e1:00.0, compute capability: 7.0", name: "/device:GPU:7"
#  device_type: "GPU"
#  memory_limit: 31965305242
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 10930206061279407716
#  physical_device_desc: "device: 7, name: Tesla V100-SXM2-32GB, pci bus id: 0000:e9:00.0, compute capability: 7.0", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 16674756359051373070
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:1"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12049648830528681321
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:2"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 13635854159107556446
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:3"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 9508813597153045649
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:4"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 7284156906947277555
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:5"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 8803501694858249869
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:6"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 9872209891256094545
#  physical_device_desc: "device: XLA_GPU device", name: "/device:XLA_GPU:7"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3968907716248282674
#  physical_device_desc: "device: XLA_GPU device"]
